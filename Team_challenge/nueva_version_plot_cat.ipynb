# %%
# Consigo la lista de subcategorías únicas
subcategories = df["Sub_Category"].unique()
print("Subcategorías disponibles:", subcategories)

# %%
# Consigo las subcategorías únicas en el DataFrame
subcategories = df["Sub_Category"].unique()

# Genero el histograma de Revenue_USD según Sub_Category
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="Revenue_USD", hue="Sub_Category", bins=20, multiple="stack", palette="Set2")

plt.title("Histograma de Revenue_USD según Sub_Category")
plt.xlabel("Revenue_USD")
plt.ylabel("Frecuencia")

plt.legend(title="Sub_Category", labels=subcategories, loc='upper right') # Genero la leyenda
plt.show()
